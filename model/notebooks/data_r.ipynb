# %%
import pandas as pd

# %%
clubs = pd.read_csv('../data/raw/clubs.csv')

# %%
clubs.head()
# Out:
#    club_id          club_code                             name  \
# 0      105    sv-darmstadt-98                  SV Darmstadt 98
# 1    11127  ural-ekaterinburg               Ural Yekaterinburg
# 2      114  besiktas-istanbul        Beşiktaş Jimnastik Kulübü
# 3       12             as-rom       Associazione Sportiva Roma
# 4      148  tottenham-hotspur  Tottenham Hotspur Football Club
#
#   domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                      L1                 NaN          27         25.6
# 1                     RU1                 NaN          30         26.5
# 2                     TR1                 NaN          30         26.6
# 3                     IT1                 NaN          26         26.3
# 4                     GB1                 NaN          30         25.5
#
#    foreigners_number  foreigners_percentage  national_team_players  \
# 0                 13                   48.1                      1
# ...

# %%
a = clubs.merge(
    pd.read_csv('../data/raw/competitions.csv'),
    left_on='domestic_competition_id',
    right_on='competition_id',
    how='inner',
    suffixes=('', '_right')
)

# %%
a[a['country_name'] == 'Ukraine'][['name', 'country_id', 'club_id']]
# Out:
#                                 name  country_id  club_id
# 25                       SC Dnipro-1         177    60551
# 26         Goverla Uzhgorod (- 2016)         177     6996
# 39              Karpaty Lviv (-2021)         177     2477
# 42                   Vorskla Poltava         177     2740
# 53             Metalist 1925 Kharkiv         177    55686
# 58                  Metalist Kharkiv         177    83678
# 72                          PFK Lviv         177    18105
# 94                   Desna Chernigiv         177    16239
# 105                   FK Obolon Kyiv         177    39097
# 122       PFK Stal Kamyanske (-2018)         177    16247
# 132              FC Ingulets Petrove         177    49364
# 166        Metalist Kharkiv (- 2016)         177     6414
# 167                      FK Mariupol         177     6993
# 172                   FK Livyi Bereh         177    86209
# 174                 FC Zorya Lugansk         177    10690
# ...

# %%
a[a['country_id'] == 177]['club_id'].unique()
# Out:
# array([60551,  6996,  2477,  2740, 55686, 83678, 18105, 16239, 39097,
#        16247, 49364,  6414,  6993, 86209, 10690, 23611, 18303, 26459,
#          338,  6992, 16245,   339,  4482, 48726,  8838,  2227, 61825,
#        63007,   660,  9007,  3592,  6994,  2783, 53646, 48332, 85465])

# %%
a[a['club_id'] == 2740][['name']]
# Out:
#                name
# 42  Vorskla Poltava
